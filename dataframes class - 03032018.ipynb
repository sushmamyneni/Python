# %%
import numpy as np
import pandas as pd

dataset = pd.read_csv("https://raw.githubusercontent.com/colaberry/Practical-Data-Science/master/Datasets/IRIS/iris.csv")
#Practical-Data-Science / Datasets / IRIS / iris.csv 

dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
dataset.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
dataset[['sepal_length','sepal_width']][2:6].head()
# Out:
#    sepal_length  sepal_width
# 2           4.7          3.2
# 3           4.6          3.1
# 4           5.0          3.6
# 5           5.4          3.9

# %%
dataset.groupby('species').count()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa                50           50            50           50
# versicolor            50           50            50           50
# virginica             50           50            50           50

# %%
dataset.groupby('species').sum()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             250.3        170.9          73.2         12.2
# versicolor         296.8        138.5         213.0         66.3
# virginica          329.4        148.7         277.6        101.3

# %%
dataset[dataset.sepal_length>5]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 14            5.8          4.0           1.2          0.2      setosa
# 15            5.7          4.4           1.5          0.4      setosa
# 16            5.4          3.9           1.3          0.4      setosa
# 17            5.1          3.5           1.4          0.3      setosa
# 18            5.7          3.8           1.7          0.3      setosa
# 19            5.1          3.8           1.5          0.3      setosa
# 20            5.4          3.4           1.7          0.2      setosa
# 21            5.1          3.7           1.5          0.4      setosa
# 23            5.1          3.3           1.7          0.5      setosa
# ...

# %%
dataset[dataset.sepal_length>5]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 14            5.8          4.0           1.2          0.2      setosa
# 15            5.7          4.4           1.5          0.4      setosa
# 16            5.4          3.9           1.3          0.4      setosa
# 17            5.1          3.5           1.4          0.3      setosa
# 18            5.7          3.8           1.7          0.3      setosa
# 19            5.1          3.8           1.5          0.3      setosa
# 20            5.4          3.4           1.7          0.2      setosa
# 21            5.1          3.7           1.5          0.4      setosa
# 23            5.1          3.3           1.7          0.5      setosa
# ...

# %%
dataset[(dataset.species=='virginica')| (dataset.sepal_length>5)]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 14            5.8          4.0           1.2          0.2      setosa
# 15            5.7          4.4           1.5          0.4      setosa
# 16            5.4          3.9           1.3          0.4      setosa
# 17            5.1          3.5           1.4          0.3      setosa
# 18            5.7          3.8           1.7          0.3      setosa
# 19            5.1          3.8           1.5          0.3      setosa
# 20            5.4          3.4           1.7          0.2      setosa
# 21            5.1          3.7           1.5          0.4      setosa
# 23            5.1          3.3           1.7          0.5      setosa
# ...

# %%
dataset[(dataset.sepal_length+dataset.sepal_width+dataset.petal_length+dataset.petal_width)>10].tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
x=dataset[['sepal_length','sepal_width','petal_length','petal_width']].head()
x
y=dataset['species'].head()
print(x)
print(y)

print(type(x))
print(type(y))
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# Name: species, dtype: object
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
# in the above example, y is created as objecttype SERIES instead of dataframe
y=dataset.filter(['species'],axis=1).head()
type(y)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.loc[:4,['petal_length']]
# Out:
#    petal_length
# 0           1.4
# 1           1.4
# 2           1.3
# 3           1.5
# 4           1.4

# %%
dataset.iloc[:,1].head()
# Out:
# 0    3.5
# 1    3.0
# 2    3.2
# 3    3.1
# 4    3.6
# Name: sepal_width, dtype: float64

# %%
dataset.iloc[2:6,1:3]
# Out:
#    sepal_width  petal_length
# 2          3.2           1.3
# 3          3.1           1.5
# 4          3.6           1.4
# 5          3.9           1.7

# %%
#use 2 dataframes(sepal, petal) one having sepal_length and the other having petal_width using loc

sepal=dataset.loc[:,['sepal_length','sepal_width']].head()
print(sepal)
petal=dataset.loc[:,['petal_length','petal_width']].head()
print(petal)
# Out:
#    sepal_length  sepal_width
# 0           5.1          3.5
# 1           4.9          3.0
# 2           4.7          3.2
# 3           4.6          3.1
# 4           5.0          3.6
#    petal_length  petal_width
# 0           1.4          0.2
# 1           1.4          0.2
# 2           1.3          0.2
# 3           1.5          0.2
# 4           1.4          0.2

# %%
# print out the dataset whose sepal_length > 5 with columns sepal_length and petal_length using loc

x=dataset.loc[dataset.sepal_length>5,['sepal_length','petal_length']].head()
x
# Out:
#     sepal_length  petal_length
# 0            5.1           1.4
# 5            5.4           1.7
# 10           5.4           1.5
# 14           5.8           1.2
# 15           5.7           1.5

# %%
x=dataset.loc[((dataset.sepal_length>5) & (dataset.petal_length > 1.5)),['sepal_length','petal_length']].head()
x
# Out:
#     sepal_length  petal_length
# 5            5.4           1.7
# 18           5.7           1.7
# 20           5.4           1.7
# 23           5.1           1.7
# 44           5.1           1.9
